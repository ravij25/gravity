# %% [markdown]
# <a href="https://colab.research.google.com/github/ravij25/gravity/blob/main/IWT_L_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import pywt
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ravij25/gravity/main/wavelet_coeffs_level0.csv")

# %%
df
# Out:
#         Level 0
# 0      7.593651
# 1      8.739571
# 2      7.930899
# 3      8.306123
# 4      5.596970
# ..          ...
# 712 -143.049615
# 713 -180.791868
# 714 -285.072727
# 715 -287.426081
# 716 -164.053311
#
# [717 rows x 1 columns]

# %%
signal = df['Level 0'].to_numpy()

# %%
wavelet = 'db4'
decomp_level = 5

# %%
coeffs = pywt.wavedec(signal, wavelet, level=decomp_level)

# %%
reconstructed_signal = pywt.waverec(coeffs, wavelet)

# %%
df_reconstructed = pd.DataFrame({'your_column': reconstructed_signal})

# %%
df_reconstructed.to_csv('reconstructed_data.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Plot the original and reconstructed signals
fig, axs = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
axs[0].plot(signal)
axs[0].set_title('Original Signal')
axs[1].plot(reconstructed_signal)
axs[1].set_title('Reconstructed Signal')
plt.tight_layout()
plt.show()
