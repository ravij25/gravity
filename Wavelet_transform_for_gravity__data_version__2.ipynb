# %% [markdown]
# <a href="https://colab.research.google.com/github/ravij25/gravity/blob/main/Wavelet_transform_for_gravity__data_version__2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pywt
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ravij25/gravity/main/kadapa2.csv")

# %%
df
# Out:
#            Lat     Long  Bouger anomaly
# 0      78.0083  17.0032             4.6
# 1      78.0250  17.0032             3.0
# 2      78.0417  17.0032             1.4
# 3      78.0583  17.0032             0.1
# 4      78.0750  17.0032            -0.9
# ...        ...      ...             ...
# 22743  79.9417  14.0003           -32.5
# 22744  79.9583  14.0003           -32.4
# 22745  79.9750  14.0003           -32.6
# 22746  79.9917  14.0003           -33.4
# 22747  80.0083  14.0003           -35.1
#
# [22748 rows x 3 columns]

# %%
# Define the level of decomposition
decomp_level = 5

# %%
# Extract the data as a numpy array
data = df['Bouger anomaly'].to_numpy()

# %%
# Define the wavelet to be used
wavelet = pywt.Wavelet('db4')

# %%
# Perform the wavelet decomposition
coeffs = pywt.wavedec(data, wavelet, level=decomp_level)

# %%
# Reconstruct the data from the wavelet coefficients
reconstructed_data = pywt.waverec(coeffs, wavelet)

# %%
# Plot the original and reconstructed data for comparison
plt.plot(data, label='Original data')
plt.plot(reconstructed_data, label='Reconstructed data')
plt.legend()
plt.show()

# %%
# Plot the original and reconstructed data for comparison
plt.figure(figsize=(28, 6))
plt.plot(data, label='Original data')
plt.plot(reconstructed_data, label='Reconstructed data')
plt.legend()
plt.show()

# %%
# Create a figure with two subplots
fig, axs = plt.subplots(2, 1, figsize=(28, 12))

# Plot the original data on the first subplot
axs[0].plot(data)
axs[0].set_title('Original Data')

# Plot the reconstructed data on the second subplot
axs[1].plot(reconstructed_data)
axs[1].set_title('Reconstructed Data')

# Show the plot
plt.show()

# %%
# Create a figure with two subplots
fig, axs = plt.subplots(2, 1, figsize=(28, 12))

# Plot the original data on the first subplot
axs[0].plot(data)
axs[0].set_title('Original Data')
axs[0].set_ylabel('Gravity Anomaly (mGal)')

# Plot the reconstructed data on the second subplot
axs[1].plot(reconstructed_data)
axs[1].set_title('Reconstructed Data')
axs[1].set_xlabel('Sample Number')
axs[1].set_ylabel('Gravity Anomaly (mGal)')

# Show the plot
plt.show()

# %%
To compute the depth of the source of a Bouguer anomaly, you can use the following formula:

scss
Copy code
depth = (2 * pi * G * density * volume) / (1000 * bouguer_anomaly)
Where:

G is the gravitational constant, which is approximately 6.67430 × 10^-11 m^3 kg^-1 s^-2.
density is the density of the material causing the anomaly in kg/m^3.
volume is the volume of the material causing the anomaly in m^3.
bouguer_anomaly is the Bouguer anomaly in mGal.
Assuming that you have the density and volume information for the source of the Bouguer anomaly, you can add the following code to compute the depth:

# %%
# Compute the depth of the source of the Bouguer anomaly
G = 6.67430e-11 # Gravitational constant
density = 2670 # Density of the source material in kg/m^3
volume = 1000 # Volume of the source material in m^3
bouguer_anomaly = df['Bouger anomaly'].mean() # Mean Bouguer anomaly in mGal

depth = (2 * np.pi * G * density * volume) / (1000 * bouguer_anomaly)

print("Depth of the source of the Bouguer anomaly: {:.2f} meters".format(depth))

# Plot the original and reconstructed data for comparison
plt.figure(figsize=(28, 6))
plt.plot(data, label='Original data')
plt.plot(reconstructed_data, label='Reconstructed data')
plt.legend()
plt.show()
# Out:
# Depth of the source of the Bouguer anomaly: -0.00 meters
